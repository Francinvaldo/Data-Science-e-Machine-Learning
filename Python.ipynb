# %%
dic = {"valor1":1 , "valor2":2}

# %%
print(dic)
# Out:
# {'valor2': 2, 'valor1': 1}

# %%
type(dic)
# Out:
# dict

# %%
print(dic['valor1'])
# Out:
# 1

# %%
dicionario = {}

# %%
type(dicionario)
# Out:
# dict

# %%
vectores = []

# %%
print(type(vectores))
# Out:
# <class 'list'>

# %%
#tuplas 

tuplas = ()

# %%
type(tuplas)
# Out:
# tuple
